# %% [markdown]
# # variables

# %%
900/4
# Out:
# 225.0

# %%
# data type

# %%
type(10 * 3)
# Out:
# int

# %%
myFloat = 1.4533665

# %%
type(myFloat)
# Out:
# float

# %%
x = "python"

# %%
type(x)
# Out:
# str

# %%
# camelCase
# smake_case

# %%
pythonLearning
python_learning

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
myBoolean = True

# %%
type(myBoolean)
# Out:
# bool

# %%
3>5
# Out:
# False

# %%
5>1
# Out:
# True

# %%
age= input("enter the age: ")
# Out:
# enter the age:  18

# %%
age
# Out:
# '18'

# %%
int(age) > 18
# Out:
# False

# %%
barcode = "ABCDE123123982"

# %%
barcode[3::]
# Out:
# 'DE123123982'

# %%
 barcode[::3]
# Out:
# 'AD228'

# %%
 barcode[::]
# Out:
# 'ABCDE123123982'

# %%
name = "niko khanjanli"

# %%
name.index("n")
# Out:
# 0

# %%
name.split()
# Out:
# ['niko', 'khanjanli']

# %%
type(name.split())
# Out:
# list

# %%
myString = "Niko"

# %%
myString.replace("N","n")
# Out:
# 'niko'

# %%
myList = [10,20,30]

# %%
type(myList)
# Out:
# list

# %%
myList = [10,20,30,40,50,60,70,80]

# %%
myList[0]
# Out:
# 10

# %%
type(myList[0])
# Out:
# int

# %%
myList[0]= 100

# %%
myList[0]
# Out:
# 100

# %%
 myList
# Out:
# [100, 20, 30, 40, 50, 60, 70, 80]

# %%
#tuple

# %%
myTuple = (10,"a","b",3.14)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[0]
# Out:
# 10

# %%
#immutability

# %%
myTuple.index("a")
# Out:
# 1

# %%
myTuple.count("a")
# Out:
# 1

# %%
resultTuple = (10,100,20)

# %%
resultList = list(resultTuple)

# %%
type(resultList)
# Out:
# list
